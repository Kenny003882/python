# %%
# 提示用户登录商店
user1 = "kenny.l"
password1 = "lzylove123."

for i in range(3,0,-1):   # 用户最多输入三次账户密码
    username = input("username:") 
    password = input("password:")

    #判断用户登录信息是否正确
    if user1 == username and password1 == password:
        print("欢迎"+user1+"登陆成功")
        break # 终止循环
    
    else:
        if i == 1:
            print("三次输入失败，请一小时后再来尝试")
        else:
            print("账号不存在或密码不正确")
            print("您还有"+str(i-1)+"次2尝试的机会") 

# 进入商店
product_list=[
    ('电脑1',9500),
    ('电脑2',800),
    ('法拉利',8800000),
    ('python入门教程',100),
    ('华为手机',6000),
 
]
saving=input('please input your money:')
shopping_car=[]
if saving.isdigit():
    saving=int(saving)
    while True:
        #打印商品内容
        for i,v in enumerate(product_list,1):
            print(i,'>>>>',v)
 
         #引导用户选择商品
        choice=input('选择购买商品编号[退出：t]：')
 
        #验证输入是否合法
        if choice.isdigit():
            choice=int(choice)
            if choice>0 and choice<=len(product_list):
                #将用户选择商品通过choice取出来
                p_item=product_list[choice-1]
 
                #如果钱够，用本金saving减去该商品价格，并将该商品加入购物车
                if p_item[1]<saving:
                    saving-=p_item[1]
 
                    shopping_car.append(p_item)
 
                else:
                    print('余额不足，还剩%s'%saving)
                print(p_item)
            else:
                print('编码不存在')
        elif choice=='t':
            print('------------您已经购买如下商品----------------')
            #循环遍历购物车里的商品，购物车存放的是已买商品
            for i in shopping_car:
                print(i)
            print('您还剩%s元'%saving)
            break
        else:
            print('invalid input')
# Out:
# username:kenny.l
# password:lzylove123.
# 欢迎kenny.l登陆成功
# please input your money:1000000
# 1 >>>> ('电脑1', 9500)
# 2 >>>> ('电脑2', 800)
# 3 >>>> ('法拉利', 8800000)
# 4 >>>> ('python入门教程', 100)
# 5 >>>> ('华为手机', 6000)
# 选择购买商品编号[退出：t]：1
# ('电脑1', 9500)
# 1 >>>> ('电脑1', 9500)
# 2 >>>> ('电脑2', 800)
# 3 >>>> ('法拉利', 8800000)
# 4 >>>> ('python入门教程', 100)
# 5 >>>> ('华为手机', 6000)
# 选择购买商品编号[退出：t]：t
# ------------您已经购买如下商品----------------
# ('电脑1', 9500)
# 您还剩990500元
